# %% [markdown]
# <a href="https://colab.research.google.com/github/abduabdulla411-sys/advanced-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("hello,how r u ?")
# Out:
# hello,how r u ?

# %%
print("hello","sep=','")
# Out:
# hello sep=','

# %%
var('name,age')
ArithmeticErrorkber 20
# Out:
#   File "/tmp/ipython-input-130032060.py", line 2
#     ArithmeticErrorkber 20
#                         ^
# SyntaxError: invalid syntax

# %%
Name = (input("Name :"))
Age = int(input("Age :"))
Address = (input("Address :"))
Phone = int(input("Phone :"))
Email = (input("Email :"))
# Out:
# Name :Abdulla
# Age :22
# Address :Abdulla Manzil
# Phone :7025212977
# Email :abduabdula@gmail.com

# %%
print(Name,Age,Address,Phone,Email)
# Out:
# Abdulla 22 Abdulla Manzil 7025212977 abduabdula@gmail.com

# %%
Name :Abdulla
Age :22
Address :Abdulla Manzil
Phone :7025212977
Email :abduabdula@gmail.com
print(f"/t{name}/t")
printf"age:{age}"
printf"phone:{phone}"
# Out:
#   File "/tmp/ipython-input-4170841428.py", line 3
#     Address :Abdulla Manzil
#                      ^
# SyntaxError: invalid syntax

# %%
Name = (input("Name :"))
Age = int(input("Age :"))
Address = (input("Address :"))
Phone = int(input("Phone :"))

print(f"\t{name}\t")
print(f"age:{age}")
print(f"address:{address}")
print(f"phone:{phone}")
# Out:
# Name :asbjja
# Age :22
# Address :advjavjon
# Phone :17971293
# 	Abdulla
# age:22
# address:Abdulla Manzil
# phone:7025212977

# %%
first_name ="Abdulla"
last_name ="P"
Full_name = first_name +" " +last_name
print(Full_name)
# Out:
# Abdulla P

# %%
my_text = """MSI Crosshair 16 HX AI Intel Core Ultra 7 255HX -
(16 GB/1 TB SSD/Windows 11 Home/8 GB Graphics/NVIDIA GeForce RTX 5060/240 Hz)
 Crosshair 16 HX AI D2XWFKG-068IN Gaming Laptop (16 Inch, Cosmos Gray, 2.5 Kg)"""
my_text
# Out:
# 'MSI Crosshair 16 HX AI Intel Core Ultra 7 255HX - \n(16 GB/1 TB SSD/Windows 11 Home/8 GB Graphics/NVIDIA GeForce RTX 5060/240 Hz)\n Crosshair 16 HX AI D2XWFKG-068IN Gaming Laptop (16 Inch, Cosmos Gray, 2.5 Kg)'

# %%
news= 'The Prime minsiter is narendra modi'
print(len(news))
# Out:
# 35

# %%
news= 'The Prime minsiter is narendra modi'
news[12::2]
# Out:
# 'nie snrnr oi'

# %%
news[-1]
# Out:
# 'i'

# %%
news[0:12]
# Out:
# 'The Prime mi'

# %%
news.upper()
# Out:
# 'THE PRIME MINSITER IS NARENDRA MODI'

# %%
news.lower()
# Out:
# 'the prime minsiter is narendra modi'

# %%
news.strip()
# Out:
# 'The Prime minsiter is narendra modi'

# %%
news.split()
# Out:
# ['The', 'Prime', 'minsiter', 'is', 'narendra', 'modi']

# %%
news.replace("Prime","Chief")
# Out:
# 'The Chief minsiter is narendra modi'

# %%
news.count("is")
# Out:
# 1

# %%
num1 = 20
num2 = 6
print(num1+num2)
# Out:
# 26

# %%
num1-num2
# Out:
# 14

# %%
num1*num2
# Out:
# 120

# %%
num1/num2
# Out:
# 3.3333333333333335

# %%
num1%num2
# Out:
# 2

# %%
num1//num2
# Out:
# 3

# %%
num1**num2
# Out:
# 64000000

# %%
num1>num2
# Out:
# True

# %%
num2>num1
# Out:
# False

# %%
num1==num2
# Out:
# False

# %%
num1>=num2
# Out:
# True

# %%
num2>=num1
# Out:
# False

# %%
num1 != num2
# Out:
# True

# %%
print (10>5 and 7>2)
# Out:
# True

# %%
print(10>5 or 7>12)
# Out:
# True

# %%
print(not(10>5 and 7>2))
# Out:
# False

# %%
print ("prime in news")
# Out:
# prime in news

# %%
news
'The finance minister announced'
# Out:
# 'The finance minister announced'

# %%
print ("finance" in news)
# Out:
# False

# %%
salary=int(input("Enter your Salary :"))
expence=int(input("Expence :"))
savings=salary-expence
print(f"your savings in {savings}")
# Out:
# Enter your Salary :15000
# Expence :10000
# your savings in 5000

# %%
current_month= int(input("Enter your salary :"))
next_month=(current_month+((0.12)*current_month))
print(f"your salary in next month is {next_month}")
# Out:
# Enter your salary :1000
# your salary in next month is 1120.0

# %%
num1=int(input("Enter an amount :"))
num2=4000
print(num1%5)
print(num1>=num2)
# Out:
# Enter an amount :10000
# 0
# True

# %%
10
1

# %%
groceries = ["milk","wheat","barley","bread"]
print(groceries)
# Out:
# ['milk', 'wheat', 'barley', 'bread']

# %%
type(groceries)
# Out:
# list

# %%
 groceries[:3]
# Out:
# ['milk', 'wheat', 'barley']

# %%
len (groceries)
# Out:
# 4

# %%
new_list = ["apple","banana","orange","kiwi","mango"]

final_list = groceries + new_list
final_list
# Out:
# ['milk',
#  'wheat',
#  'barley',
#  'bread',
#  'apple',
#  'banana',
#  'orange',
#  'kiwi',
#  'mango']

# %%
new_list2 = ["chips","biscuits"]
final_list.extend(new_list2)

# %%
final_list
# Out:
# ['milk',
#  'wheat',
#  'barley',
#  'bread',
#  'apple',
#  'banana',
#  'orange',
#  'kiwi',
#  'mango',
#  'chips',
#  'biscuits']

# %%
final_list.append("curd")
final_list.insert(2,"ice cream")

# %%
final_list.reverse()
final_list
# Out:
# ['milk',
#  'wheat',
#  'ice cream',
#  'barley',
#  'bread',
#  'apple',
#  'banana',
#  'orange',
#  'kiwi',
#  'mango',
#  'chips',
#  'biscuits',
#  'curd']

# %%
final_list.sort()
final_list
# Out:
# ['apple',
#  'banana',
#  'barley',
#  'biscuits',
#  'bread',
#  'chips',
#  'curd',
#  'ice cream',
#  'kiwi',
#  'mango',
#  'milk',
#  'orange',
#  'wheat']

# %%
final_list.pop()
final_list
# Out:
# ['apple',
#  'banana',
#  'barley',
#  'biscuits',
#  'bread',
#  'chips',
#  'curd',
#  'ice cream',
#  'kiwi',
#  'mango',
#  'milk',
#  'orange']

# %%
final_list.reverse()
final_list
# Out:
# ['orange',
#  'milk',
#  'mango',
#  'kiwi',
#  'ice cream',
#  'curd',
#  'chips',
#  'bread',
#  'biscuits',
#  'barley',
#  'banana',
#  'apple']

# %%
final_list.pop(2)
final_list
# Out:
# ['orange',
#  'milk',
#  'kiwi',
#  'ice cream',
#  'curd',
#  'chips',
#  'bread',
#  'biscuits',
#  'barley',
#  'banana',
#  'apple']

# %%
final_list.remove("orange")
final_list
# Out:
# ['milk',
#  'kiwi',
#  'ice cream',
#  'curd',
#  'chips',
#  'bread',
#  'biscuits',
#  'barley',
#  'banana',
#  'apple']

# %%
final_list.clear()
final_list
# Out:
# []

# %%
final_list.sort() #reverse=True/False
final_list
# Out:
# []

# %%
final_list[1:3] = ["pen","pencil"]
final_list
# Out:
# ['pen', 'pen', 'pencil']

# %%
playlist1=["autumn"]
playlist2=["winter"]
playlist3=["summer"]
playlist=playlist1+playlist2+playlist3
playlist
# Out:
# ['autumn', 'winter', 'summer']

# %%
final_list.append("monsoon")

# %%
final_list
# Out:
# ['pen', 'pen', 'pencil', 'monsoon']

# %%
playlist.append("monsoon")

# %%
playlist
# Out:
# ['autumn', 'winter', 'summer', 'monsoon']

# %%
playlist.sort()
playlist
# Out:
# ['autumn', 'monsoon', 'summer', 'winter']

# %%
playlist.pop(1)
playlist
# Out:
# ['autumn', 'summer', 'winter']

# %%
playlist.insert(2,"rain")

# %%
playlist
# Out:
# ['autumn', 'summer', 'rain', 'winter']

# %%
playlist.reverse()
playlist
# Out:
# ['winter', 'rain', 'summer', 'autumn']

# %%
playlist.extend(new_list2)
playlist
# Out:
# ['winter', 'rain', 'summer', 'autumn', 'chips', 'biscuits']

# %%
playlist.append("toy")
playlist
# Out:
# ['winter', 'rain', 'summer', 'autumn', 'chips', 'biscuits', 'toy']

# %%
nums=[1.34,43,23,78,56]
min(nums)
# Out:
# 1.34

# %%
max(nums)
# Out:
# 78

# %%
sum(nums)
# Out:
# 201.34

# %%
avg = sum(nums)/len(nums)

# %%
avg
# Out:
# 40.268

# %%
nums.index(max(nums))
# Out:
# 3

# %%
playlist.index("autumn")
# Out:
# 3

# %%
toys=("optimus","bumblebee","woody","grove")
type(toys)
# Out:
# tuple

# %%
plane=("boing","phantom")
toys += plane
toys
# Out:
# ('optimus',
#  'bumblebee',
#  'woody',
#  'grove',
#  'boing',
#  'phantom',
#  'boing',
#  'phantom')

# %%
toys.index("boing")
# Out:
# 4

# %%
fruits ={"apple","orange","lemon"}
type(fruits)
# Out:
# set

# %%
fruits
# Out:
# {'apple', 'lemon', 'orange'}

# %%
fruits ={"apple","orange","lemon","apple"}
type(fruits)
# Out:
# set

# %%
fruits
# Out:
# {'apple', 'lemon', 'orange'}

# %%
fruits.add("pineapple")

# %%
fruits
# Out:
# {'apple', 'lemon', 'orange', 'pineapple'}

# %%
fruits.pop()
# Out:
# 'pineapple'

# %%
fruits
# Out:
# {'apple', 'lemon', 'orange'}

# %%
fruits.remove("apple")

# %%
fruits
# Out:
# {'lemon', 'orange'}

# %%
fruits.discard("orange")

# %%
fruits
# Out:
# {'lemon'}

# %%
print(1)
# Out:
# 1

# %%
car = {
    "brand" : "Ford",
    "model" : "Mustang",
    "year" :2025,
    "cur_year" :2025
}
car
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2025, 'cur_year': 2025}

# %%
car["brand"]
# Out:
# 'Ford'

# %%
car["model"]
# Out:
# 'Mustang'

# %%
car
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2025, 'cur_year': 2025}

# %%
car["year"]
# Out:
# 2025

# %%
car2 = dict(brand="Rolceroyce",model="phantom",year=2020)

# %%
car2
# Out:
# {'brand': 'Rolceroyce', 'model': 'phantom', 'year': 2020}

# %%
car2["model"]
# Out:
# 'phantom'

# %%
car2.get("brand")
# Out:
# 'Rolceroyce'

# %%
len(car2)
# Out:
# 3

# %%
car2.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
car2.values()
# Out:
# dict_values(['Rolceroyce', 'phantom', 2020])

# %%
car2['model'] = "Boattail"

# %%
car2
# Out:
# {'brand': 'Rolceroyce', 'model': 'Boattail', 'year': 2020}

# %%
car2['color'] = "Blue"
car2
# Out:
# {'brand': 'Rolceroyce', 'model': 'Boattail', 'year': 2020, 'color': 'Blue'}

# %%
car2.update({"cylinders":6,"engine":"Petrol","color":"Black"})

# %%
car2
# Out:
# {'brand': 'Rolceroyce',
#  'model': 'Boattail',
#  'year': 2020,
#  'color': 'Black',
#  'cylinders': 6,
#  'engine': 'Petrol'}

# %%
car2.items()
# Out:
# dict_items([('brand', 'Rolceroyce'), ('model', 'Boattail'), ('year', 2020), ('color', 'Black'), ('cylinders', 6), ('engine', 'Petrol')])

# %%
#remove

car2.popitem()
# Out:
# ('engine', 'Petrol')

# %%
car2.pop("cylinders")
# Out:
# 6

# %%
car2
# Out:
# {'brand': 'Rolceroyce', 'model': 'Boattail', 'year': 2020, 'color': 'Black'}

# %%
del car2['model']

# %%
car2
# Out:
# {'brand': 'Rolceroyce', 'year': 2020, 'color': 'Black'}

# %%
car2
# Out:
# {'brand': 'Rolceroyce', 'year': 2020, 'color': 'Black'}

# %%
emp1 = {"name": "Raj",
        "salary": 45000,
        "dept": "HR"}
emp2 = {"name": "Manoj",
        "salary": 35000,
        "dept": "IT"}
emp3 = {"name": "Sumin",
        "salary": 40000,
        "dept": "Finance",
        "grade": "M1"}

employees= {"employee1":emp1,
             "employee2":emp2,
             "employee3":emp3}

employees
# Out:
# {'employee1': {'name': 'Raj', 'salary': 45000, 'dept': 'HR'},
#  'employee2': {'name': 'Manoj', 'salary': 35000, 'dept': 'IT'},
#  'employee3': {'name': 'Sumin',
#   'salary': 40000,
#   'dept': 'Finance',
#   'grade': 'M1'}}

# %%
employees ={
    "employee1" :emp1,
    "employee2" :emp2,
    "employee3" :emp3
}
employees
# Out:
# {'employee1': {'name': 'Raj', 'salary': 45000, 'dept': 'HR'},
#  'employee2': {'name': 'Manoj', 'salary': 35000, 'dept': 'IT'},
#  'employee3': {'name': 'Sumin',
#   'salary': 40000,
#   'dept': 'Finance',
#   'grade': 'M1'}}

# %%
employees['employee1']
# Out:
# {'name': 'Raj', 'salary': 45000, 'dept': 'HR'}

# %%
employees['employee2']
# Out:
# {'name': 'Manoj', 'salary': 35000, 'dept': 'IT'}

# %%
employees['employee2']
# Out:
# {'name': 'Manoj', 'salary': 35000, 'dept': 'IT'}

# %%
contact = {
    "akber" : 12345,
    "asif" : 67890,
    "anand" : 90876,
    "ashkar" : 54321
}
contact
# Out:
# {'akber': 12345, 'asif': 67890, 'anand': 90876, 'ashkar': 54321}

# %%
contact['asif'] = 638363
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-988451909.py in <cell line: 0>()
# ----> 1 contact['asif'] = 638363
#
# NameError: name 'contact' is not defined

# %%
# Out:
# {'akber': 12345, 'asif': '638363', 'anand': 90876, 'ashkar': 54321}

# %%
contact.update({"akber":78890,"anand":46965})

# %%
contact
# Out:
# {'akber': 78890, 'asif': 638363, 'anand': 46965, 'ashkar': 54321}

# %%
del contact['ashkar']

# %%
contact
# Out:
# {'akber': 78890, 'asif': 638363, 'anand': 46965}

# %%
contact.popitem()

contact
# Out:
# {'akber': 78890, 'asif': 638363}

# %%
del contact

# %%
contact
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-896168541.py in <cell line: 0>()
# ----> 1 contact
#
# NameError: name 'contact' is not defined

# %%
contact = {
    "akber" : 12345,
    "asif" : 67890,
    "anand" : 90876,
    "ashkar" : 54321
}
contact
# Out:
# {'akber': 12345, 'asif': 67890, 'anand': 90876, 'ashkar': 54321}

# %%
contact.values()
# Out:
# dict_values([12345, 67890, 90876, 54321])

# %%
contact.keys()
# Out:
# dict_keys(['akber', 'asif', 'anand', 'ashkar'])

# %%
movies = ["avatar","titanic","rrr","bahubali"]
ratings = [9.0,7.8,8.9,10]

# %%
movie_rating = dict(zip(movies,ratings))
movie_rating
# Out:
# {'avatar': 9.0, 'titanic': 7.8, 'rrr': 8.9, 'bahubali': 10}

# %%
 a=20
 b=10

# %%
if a>b:
   print("a is greater")
elif a==b:
  print("a equal to b")
else:
    print("b is greater")
# Out:
# a is greater

# %%
Student_mark = int(input("Enter your marks :"))
if Student_mark >= 90:
   print("a")
elif Student_mark >=80:
   print("b")
elif Student_mark >=70:
   print("c")
elif Student_mark >=60:
   print("d")
else:
   print("Fail")
# Out:
# Enter your marks :70
# c

# %%
wheather = (input("Enter wheather :"))
if wheather == "sunny":
   print("Take sunglasses")
elif wheather == "rainy":
   print("take umbrella")
elif wheather == "cloudy":
   print("might rain")
else:
   print("Fail")
# Out:
# Enter wheather :sunny
# Take sunglasses

# %%
education = (input("Enter your education :"))
age = int(input("Enter your age :"))
if age >18:
  if education == "higher secondary":
     print("you r eligible for higher studies")
  else:
     print("you r not eligible for higher studies")
# Out:
# Enter your education :higher secondary
# Enter your age :20
# you r eligible for higher studies

# %%
x = int(input("Enter your education :"))
print("greater")if x > 5 else print("smaller")
# Out:
# Enter your education :7
# greater

# %%
marks = 0
result = "pass" if marks>30 else "fail"
if result =="pass":
   print("Awarded with A grade")
if result =="fail":
   print("Awarded with big slap")
# Out:
# Awarded with big slap

# %%
temperature =32

weather = {"status":"hot" if temperature >30 else "cold"}
weather
# Out:
# {'status': 'hot'}

# %%
item1 = int(input("item :"))
item2 = int(input("pad :"))
item3 =  int(input("laptop :"))
item4 = int(input("headphone :"))
item5 = int(input("powerbank :"))

if mobile+ipad+laptop

# %%
price={600,750,700,100,200}
total=sum(price)
offer=total/100*20
if total > 2000:
  print("you got some discount")
  print("your discount is",offer)
# Out:
# you got some discount
# your discount is 470.0

# %%
price = [300,200,340,2100,40]
total_bill =sum(prices)
if total_bill

# %%
fruits = ["apple","orange","banana"]
for fr in fruits:
  print(fr)
# Out:
# apple
# orange
# banana

# %%
for i in range(10):
  print(f" square of {i} is {i**2}")
# Out:
#  square of 0 is 0
#  square of 1 is 1
#  square of 2 is 4
#  square of 3 is 9
#  square of 4 is 16
#  square of 5 is 25
#  square of 6 is 36
#  square of 7 is 49
#  square of 8 is 64
#  square of 9 is 81

# %%
grocery_list=["apples","bananas","milk","bread","eggs"]

for item in grocery_list:
  if item == "milk":
    print(" item found")
  else:
    print("item not found")
# Out:
# item not found
# item not found
#  item found
# item not found
# item not found

# %%
grocery_list=["apples","bananas","milk","bread","eggs"]

for item in grocery_list:
  if item == 'milk':
    print(item,"present")
    break
  else:
    if item == "bananaa":
      continue
    print("item not present")
# Out:
# item not present
# item not present
# milk present

# %%
savings = [2000,2500,0,3000,1000,5000]

for i in savings:
  if i ==0 :
   continue
  if i>4000 :
    print("you are rich u got more than 4000 in savings")
# Out:
# you are rich u got more than 4000 in savings

# %%
savings = [2000,2500,0,3000,1000,5000]
total=0
for amount in savings:
  if amount == 0 :

   if i > 4000 :
     print(f"you are rich u got more than 4000 in savings is {amount}")
total += amount
print(total)
savings=tuple(savings)
print(savings)
# Out:
# you are rich u got more than 4000 in savings is 0
# 5000
# (2000, 2500, 0, 3000, 1000, 5000)

# %%
numbers=["9847873427","7025212977","9988776655","986866467","986989","7986875363"]
valid_count =0
invalid_count =0
valid_nums = set()
for num in numbers:
  if len(num)!=10:
    invalid_count +=1
    continue
  else :
    print("valid")
    valid_count +=1
    valid_nums.add(num)

print(f"valid numbers are {valid_nums}")
print(valid_nums)
# Out:
# valid
# valid
# valid
# valid
# valid numbers are {'7986875363', '7025212977', '9988776655', '9847873427'}
# {'7986875363', '7025212977', '9988776655', '9847873427'}

# %%
i=1
while i<10:
 print(i**1)
 i +=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
savings_goal = 10000
current_sav = 0

monthly_dep = 1500

months = 0
while current_sav < savings_goal:
  current_sav += monthly_dep
  months +=1
else:
    print("you reached your goal")

    print(f"it will take{months} months to achieve your goal of {savings_goal}")
# Out:
# you reached your goal
# it will take7 months to achieve your goal of 10000

# %%
student_grades = {"Anu":85,"Bob":63,"John":45,"Sam":55,"Ryan":52}
for i in student_grades.keys():
  print(i)
# Out:
# Anu
# Bob
# John
# Sam
# Ryan

# %%
for i,j in student_grades.items():
  print(i,":",j)
  if j >50:
    print(f"{i} scared A grade")
  else:
    print(f"{i} scared B grade")
# Out:
# Anu : 85
# Anu scared A grade
# Bob : 63
# Bob scared A grade
# John : 45
# John scared B grade
# Sam : 55
# Sam scared A grade
# Ryan : 52
# Ryan scared A grade

# %%
emp1 = {"name": "Raj",
        "salary": 45000,
        "dept": "HR"}
emp2 = {"name": "Manoj",
        "salary": 35000,
        "dept": "IT"}
emp3 = {"name": "Sumin",
        "salary": 40000,
        "dept": "Finance",
        "grade": "M1"}

employees= {"employee1":emp1,
             "employee2":emp2,
             "employee3":emp3}

employees
# Out:
# {'employee1': {'name': 'Raj', 'salary': 45000, 'dept': 'HR'},
#  'employee2': {'name': 'Manoj', 'salary': 35000, 'dept': 'IT'},
#  'employee3': {'name': 'Sumin',
#   'salary': 40000,
#   'dept': 'Finance',
#   'grade': 'M1'}}

# %%
for empcode,empdetail in employees.items():
  for k,val in empdetail.items():
    if k=="Name" and val=="Raj":
      print("Raj found")

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))


if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

print("The largest number is:", largest)

# %% [markdown]
# Write a python program to find the largest of 3 numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

print("The largest number is:", largest)
# Out:
# Enter first number: 15
# Enter second number: 14
# Enter third number: 16
# The largest number is: 16

# %% [markdown]
# Write a python program to find the numbers divisible by 3 and 7 from 100 to 800

# %%
for num in range(100, 801):
    if num % 3 == 0 and num % 7 == 0:
        print(num)
# Out:
# 105
# 126
# 147
# 168
# 189
# 210
# 231
# 252
# 273
# 294
# 315
# 336
# 357
# 378
# 399
# 420
# 441
# 462
# 483
# 504
# 525
# 546
# 567
# 588
# 609
# 630
# 651
# 672
# 693
# 714
# 735
# 756
# 777
# 798

# %% [markdown]
# Write a python program to find the count of numbers divisible by 8 from 1 to 1000

# %%
count = 0

for num in range(1, 1001):
    if num % 8 == 0:
        count += 1

print("Count of numbers divisible by 8 from 1 to 1000 is", count)
# Out:
# Count of numbers divisible by 8 from 1 to 1000 is 125

# %% [markdown]
# Write a Python program to construct the following pattern, using for loop.
# *
# **
# ***
# ****
# *****

# %%
for i in range(1, 6):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# Write a Python program using for loop that will iterate from 1 to 15. For each
# iteration, check if the current number is odd or even, and display the message to the
# screen as odd or even.
# Sample input: 1….15
# Sample output: 1-odd 2-even …. 15-odd

# %%
for i in range(1, 16):
    if i % 2 == 0:
        print(i, "-even")
    else:
        print(i, "-odd")
# Out:
# 1 -odd
# 2 -even
# 3 -odd
# 4 -even
# 5 -odd
# 6 -even
# 7 -odd
# 8 -even
# 9 -odd
# 10 -even
# 11 -odd
# 12 -even
# 13 -odd
# 14 -even
# 15 -odd

# %% [markdown]
# Write a Python program that takes an integer as input and calculates the sum of its digits

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

c=(a+b)
print(c)
# Out:
# Enter first number: 2
# Enter second number: 4
# 6.0

# %%
n=int(input("Enter the number"))
fact=1
for i in range(1,n+1):
  fact=fact*i
print("factorial:",fact)
# Out:
# Enter the number8
# factorial: 40320

# %% [markdown]
# heyword function_name (parameter):
# #statement
# return expression

# %%
def multiply(num):
  print(num*2)

multiply(2)
# Out:
# 4

# %% [markdown]
# num =parameter
# multuply(argument)

# %%
def greed_person(name):
  print(f"hello {name}")

greed_person("akber")
# Out:
# hello akber

# %% [markdown]
# types of argument

# %%
def send_gift(recipient,gift):
  print(f"Sending {gift} to {recipient}!")
send_gift("Akber","Watch")
print()
# Out:
# Sending Watch to Akber!

# %%
def send_gift(recipient,gift):
  print(f"Sending {gift} to {recipient}!")
send_gift(gift="ball", recipient="Asif")
# Out:
# Sending ball to Asif!

# %% [markdown]
# arbitrary

# %%
def send_gift(recipient,*gift="a rose"):
  print(f"Sending {gift} to {recipient}!")
send_gift(recipient

# %% [markdown]
# keywords

# %%
def send_gift(recipient, *gifts):
  print(f"Sending {gifts} to {recipient}!")
send_gift("Dasy","Flowers","Card")
# Out:
# Sending ('Flowers', 'Card') to Dasy!

# %% [markdown]
#    abs()  absolute value
#     all()  any()   basestring()   bool()    bytearray() array o

# %% [markdown]
# default

# %%
def book_trip(destination,transport):
  print(f"Booking a {transport} to {destination}.")
book_trip("paris", "flight")
# Out:
# Booking a flight to paris.

# %% [markdown]
# same fn with keyword argument

# %%
def book_trip(destination,transport):
  print(f"Booking a {transport} to {destination}.")
book_trip(destination="paris", transport="flight")
# Out:
# Booking a flight to paris.

# %%
def book_trip(destination="paris",transport="flight"):
  print(f"Booking a {transport} to {destination}.")
book_trip()
# Out:
# Booking a flight to paris.

# %%
def book_trip(destination="Hawaii",transport="flight",object="hat"):
  print(f"Booking a {transport} to {destination} with a {object}.")

book_trip()
# Out:
# Booking a flight to Hawaii with a hat.

# %%
def pack(destination, *items):
    print(f"Trip to {destination} Packing:(items)")


pack("Hawaii","swimsuit","hat")
# Out:
# Trip to Hawaii Packing:(items)

# %%
def add_numbers(a,b):
  print(a+b)
result = add_numbers(10,20)
# Out:
# 30

# %%
def add_numbers(a,b):
  return(a + b)
result = add_numbers(10,20)

# %%
def add_ten(numbers):
   print(numbers + 10)

my_result = add_ten(5)
final_answer = my_result * 2
print(f"The final answer is : {final_answer}")
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1809959986.py in <cell line: 0>()
#       3
#       4 my_result = add_ten(5)
# ----> 5 final_answer = my_result * 2
#       6 print(f"The final answer is : {final_answer}")
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %% [markdown]
# print  doesnt store output
# return stores output

# %%
def add_ten(numbers):
   return(numbers + 10)

my_result = add_ten(5)
final_answer = my_result * 2
print(f"The final answer is : {final_answer}")
# Out:
# The final answer is : 30

# %% [markdown]
# pass statement
# for creating fn place holder

# %% [markdown]
# lamda fn

# %%
def square(x):
  sq = x * x
  return sq

square(5)
# Out:
# 25

# %% [markdown]
# variable      :   fn

# %%
re = lambda x:x*x
square(5)
# Out:
# 25

# %%
addition = lambda x,y : x+y
addition(10,20)
# Out:
# 30

# %%
is_pass = lambda marks: "pass" if marks>40 else "fail"
is_pass(50)
# Out:
# 'pass'

# %% [markdown]
# map fn
# first  parameter should be fn
# sec    iterative form structure

# %%
def square(x):
  sq = x * x
  return sq

numbers =[1,2,3,4,5]
squares = map(square,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers =[1,2,3,4,5]
squares = map(lambda x:x*x,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers =[1,2,3,4,5]
squares = list(map(lambda x:x*x,numbers))
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a =[1,2,3]
list_b =[4,5,6]
sum_list = list(map(lambda x,y:x+y,list_a,list_b))
sum_list
# Out:
# [5, 7, 9]

# %%
list_a = [1,-2,3,-4,-5,6,7,8]
positive_list = list(filter(lambda x:x>0,list_a))
positive_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-79904031.py in <cell line: 0>()
#       1 list_a = [1,-2,3,-4,-5,6,7,8]
# ----> 2 positive_list = list(filter(lambda x:x>0,list_a))
#       3 positive_list
#       4
#
# TypeError: 'list' object is not callable

# %% [markdown]
# git init---git clone---git pull---git status---git add---git commmit---git push---merge
